# %% [markdown]
# This is a notebook which will help you get started with the dataset '300 Years of British Patents'!  :)

# %% [markdown]
# ## Load the dataset

# %% [markdown]
# The dataset consists of two gzip-compressed JSONL files.
#
# The easiest way to load the dataset is by using the 'load_dataset' function from the HuggingFace 'datasets' library.

# %%
# %%capture
# !pip install datasets
# !pip install transformers

# %%
from datasets import load_dataset
import pandas as pd
from transformers import pipeline, AutoModelForTokenClassification, AutoModelForSequenceClassification, AutoTokenizer

# %% [markdown]
# #### Download data from HuggingFace

# %%
# to download the text data as a HF dataset:
dataset_all_years = load_dataset(
    "matthewleechen/300YearsOfBritishPatents",
    data_files="texts.jsonl.gz"
)
# Out:
# README.md:   0%|          | 0.00/6.54k [00:00<?, ?B/s]
# texts.jsonl.gz:   0%|          | 0.00/1.69G [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
# to download entities as a HF dataset:
dataset_all_entities = load_dataset(
    "matthewleechen/300YearsOfBritishPatents",
    data_files="entities.jsonl.gz"
)
# Out:
# entities.jsonl.gz:   0%|          | 0.00/32.2M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
### you can subset the dataset to years you want in a couple of ways

# subset to a number of years
years_of_interest = [1784, 1826]

# get text data for only those years
dataset_subset_specified = dataset_all_years["train"].filter(
    lambda x: x["year"] in years_of_interest
)

# or get text data for a range of years
dataset_subset_range = dataset_all_years["train"].filter(
    lambda x: 1789 <= x["year"] <= 1792
)
# Out:
# Filter:   0%|          | 0/322874 [00:00<?, ? examples/s]
# Exception ignored in: <function _xla_gc_callback at 0x7d8dbb224790>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 96, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
# Filter:   0%|          | 0/322874 [00:00<?, ? examples/s]

# %% [markdown]
# #### Inspect the dataset structure

# %%
# inspect datasetdict
print(dataset_all_years)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['patent_id', 'year', 'patent_title', 'full_text', 'word_tokens', 'predicted_BPO_classes'],
#         num_rows: 322874
#     })
# })

# %%
# inspect datasetdict
print(dataset_all_entities)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['patent_id', 'year', 'front_page_entities'],
#         num_rows: 322874
#     })
# })

# %%
# variables in the dataset and their data types
dataset_all_years['train'].features
# Out:
# {'patent_id': Value(dtype='string', id=None),
#  'year': Value(dtype='int64', id=None),
#  'patent_title': Value(dtype='string', id=None),
#  'full_text': [{'page_num': Value(dtype='int64', id=None),
#    'page_text': Value(dtype='string', id=None)}],
#  'word_tokens': Sequence(feature=Value(dtype='string', id=None), length=-1, id=None),
#  'predicted_BPO_classes': Sequence(feature=Value(dtype='string', id=None), length=-1, id=None)}

# %%
# the text data is represented in the data as a dictionary, here we display one
dataset_all_years['train'][123456]
# Out:
# {'patent_id': 'GB188100826A',
#  'year': 1881,
#  'patent_title': 'IMPROVE- MENTS IN TOBACCO-POUCHES',
#  'full_text': [{'page_num': 1,
#    'page_text': 'LETTERS PATENT to James Burbridge, Manager at Messrs. W. Warne and Co.\'s\nIndia Rubber Works, Tottenham, Middlesex, for an Invention of "IMPROVE-\nMENTS IN TOBACCO-POUCHES."\nPROVISIONAL SPECIFICATION left by the said James Burbridge at the\nOffice of the Commissioners of Patents on the 26th February 1881.\nJAMES BURBRIDGE, Manager at Messrs. W. Warne & Co.\'s India Rubber Works,\nTottenham, Middlesex. "IMPROVEMENTS IN TOBACCO POUCHES."\nThis Invention relates to a novel construction of pouch to be used for the\nreception of tobacco, fusees, and other materials used by smokers, the object being\nto obtain a compact and secure receptacle for such articles.\nTo this end we cut from a sheet of plastic rubber compound 2 pieces of any\ndesired form, say semi elliptical, and of corresponding size, and place them together\nback to back so as to form a foundation or stiffening piece for the pouch. If\ndesired, we may insert at different places between these two pieces of rubber metal\nor other plates which will prevent the rubber from adhering together when pressure\nis applied, and thus one, two, or more pockets will be formed in which to place\ncigarette paper books or matches. On either side of this foundation piece a\nsimilarly shaped piece of plastic rubber compound is attached by its edges, and\ninto the spaces between the external pieces and the foundation plate a suitable\nquantity of water or other liquid is injected, the opening left for this purpose being\nimmediately closed up.\nA cap piece of sheet rubber of suitable form is next applied to the pouch, and is\nsecured to the straight edge thereof by solution, which, when pressure is applied,\ncauses the cap piece to adhere to the body of the pouch.\nSome powdered talc or other suitable material is inserted under the cap piece\nto prevent it adhering to the body of the pouch, except at those parts which have\nreceived the solution.'},
#   {'page_num': 2,
#    'page_text': 'The formed article is now placed in the mould to be vulcanized in the usual\nmanner.\nAfter vulcanization all the joins will be found firmly united together, and the\npouch will be set according to the form of the mould.\nTo open the pouch and let out the water it will be necessary to turn back the\ncap piece and open the pockets in which the water is enclosed by running a sharp\nknife along the joint at the straight end of the pouch, after which the metal or\nother plates are drawn out of their pockets in the foundation piece, and the\nmoulded india rubber tobacco pouch, containing two pockets for tobacco and\nvarious smaller pockets, is completed.'},
#   {'page_num': 3,
#    'page_text': 'SPECIFICATION in pursuance of the conditions of the Letters Patent filed by\nthe said James Burbridge in the Great Seal Patent Office on the 24th August\n1881.\nJAMES BURBRIDGE, Manager at Messrs. Warne & Co.\'s India Rubber Works,\nTottenham, Middlesex. "IMPROVEMENTS IN TOBACCO POUCHES."\nThis Invention relates to a novel construction of pouch to be used for the\nreception of tobacco, fusees, and other materials used by smokers, the object being\nto obtain a compact and secure receptacle for such articles.\nIn the accompanying Drawing I have shewn my improved pouch in front view\nat Fig. 1 and in cross section at Fig. 2. In manufacturing this improved pouch I\ncut from a sheet of plastic rubber compound two pieces of semi-elliptical form and\ncorresponding size, such as that shewn in Fig. 1a, and place them back to back so as\nto form a foundation or stiffening piece for the pouch.\nBetween these two pieces of rubber shewn in cross section at a, a\', Fig. 2, I\ninsert one, two, or more metal or other plates to prevent the rubber pieces a, a²,\nfrom adhering together when pressure is applied, and thus one, two, or more\npockets will be formed in the foundation or stiffening piece suitable for receiving\ncigarette paper books, as shewn at Fig. 2, or matches and other materials used by\nsmokers. On either side of this foundation piece I attach similarly shaped\npieces b, b\', of plastic rubber compound, and into the spaces between these external\npieces and the foundation plate I inject water or other suitable liquid, the opening\nleft for this purpose being immediately afterwards closed up.\nI next apply to the pouch a cap-piece c of sheet rubber, and I secure it to the\nstraight edge and ends thereof by a solution of india rubber, which, when pressure\nis applied, causes the cap-piece to adhere to the body of the pouch.\nIn order to prevent the cap-piece c adhering to the body of the pouch except at\nthose parts which have received the solution I insert some powdered tale or other\nsuitable material under the cap-piece before the pouch is vulcanized.\nThe article thus far manufactured I place in a mould suitably formed and\nproportioned to impart to the pouch the required form during the process of\nvulcanization.\nDuring the vulcanizing operation the water or other liquid confined in the pouch\nwill be converted into steam which will expand and distend the rubber causing it\nto completely fill the mould, and at the same time firmly unite the joinings and\ngive to the pouch a permanent set corresponding to the internal form of the\nmould.\nWhen the vulcanizing process is completed I turn back the cap-piece and open\nthe pockets in which the water is enclosed by running a sharp knife along the\njoining at the straight end of the pouch and let out the water, I then run the knife\nalong the joinings at the part or parts where the pockets in the stiffening pieces\nare formed and remove the enclosed metal or other plates. The moulded india\nrubber tobacco pouch containing side pockets for tobacco and a central pocket or\npockets for the reception of cigarette-paper books, matches, and other paraphernalia\nof the smoker is now complete.\nAt Figures 3, 4, and 5, I have shewn a modified form of cover for closing one\nside of my improved pouch; Fig. 3 is a front view, and Fig. 4 a cross section of\nthe pouch closed, and Fig. 5 a front view of the pouch opened. In these Figures\nthe parts a, a, b, b¹, are similar to those already described with reference to\nFigures 1 and 2, and the pockets in the foundation piece are formed in the same\nmanner. Instead however of employing a cap-piece c formed as shewn in those\nFigures I prolong one side of the cap-piece, as seen at c\', Figures 4 and 5, making'},
#   {'page_num': 4,
#    'page_text': 'it correspond to the external form of the pouch, and to the outer edges of the flap\nthus formed I attach by solution a piece c² so as to form a pocket into which the\nrounded portion of the pouch can be inserted. The external form of the pouch\nmay be varied as may be desired without departing from my Invention.\nIt will be evident that instead of two side pockets for tobacco the pouch can be\nmade with only one, in which case the piece b¹ and the portion of the cap piece o\non that side will be dispensed with.\nHaving now described my Invention of "Improvements in Tobacco Pouches,"\nand explained the manner of carrying the same into effect, I wish it to be understood\nthat under the above in part recited Letters Patent, I claim,\nThe manufacture from sheet rubber of moulded tobacco pouches with side and\ncentral pockets arranged as above described or any mere modification thereof.\n•\nIn witness whereof, I, the said James Burbridge, have hereunto set my hand\nand seal, the Twenty third day of August, in the year of our Lord One\nthousand eight hundred and eighty one.\nJAMES DURDRIDGE,\n(L.S.)'}],
#  'word_tokens': ['letters',
#   'patent',
#   'to',
#   'james',
#   'burbridge',
#   'manager',
#   'at',
#   'messrs.',
#   'w.',
#   'warne',
#   'and',
#   'co.',
#   "'s",
#   'india',
#   'rubber',
#   'works',
#   'tottenham',
#   'middlesex',
#   'for',
#   'an',
#   'invention',
#   'of',
#   'improve',
#   'ments',
#   'in',
#   'tobacco',
#   'pouches',
#   'provisional',
#   'specification',
#   'left',
#   'by',
#   'the',
#   'said',
#   'james',
#   'burbridge',
#   'at',
#   'the',
#   'office',
#   'of',
#   'the',
#   'commissioners',
#   'of',
#   'patents',
#   'on',
#   'the',
#   'february',
#   'james',
#   'burbridge',
#   'manager',
#   'at',
#   'messrs.',
#   'w.',
#   'warne',
#   'co.',
#   "'s",
#   'india',
#   'rubber',
#   'works',
#   'tottenham',
#   'middlesex',
#   'improvements',
#   'in',
#   'tobacco',
#   'pouches',
#   'this',
#   'invention',
#   'relates',
#   'to',
#   'a',
#   'novel',
#   'construction',
#   'of',
#   'pouch',
#   'to',
#   'be',
#   'used',
#   'for',
#   'the',
#   'reception',
#   'of',
#   'tobacco',
#   'fusees',
#   'and',
#   'other',
#   'materials',
#   'used',
#   'by',
#   'smokers',
#   'the',
#   'object',
#   'being',
#   'to',
#   'obtain',
#   'a',
#   'compact',
#   'and',
#   'secure',
#   'receptacle',
#   'for',
#   'such',
#   'articles',
#   'to',
#   'this',
#   'end',
#   'we',
#   'cut',
#   'from',
#   'a',
#   'sheet',
#   'of',
#   'plastic',
#   'rubber',
#   'compound',
#   'pieces',
#   'of',
#   'any',
#   'desired',
#   'form',
#   'say',
#   'semi',
#   'elliptical',
#   'and',
#   'of',
#   'corresponding',
#   'size',
#   'and',
#   'place',
#   'them',
#   'together',
#   'back',
#   'to',
#   'back',
#   'so',
#   'as',
#   'to',
#   'form',
#   'a',
#   'foundation',
#   'or',
#   'stiffening',
#   'piece',
#   'for',
#   'the',
#   'pouch',
#   'if',
#   'desired',
#   'we',
#   'may',
#   'insert',
#   'at',
#   'different',
#   'places',
#   'between',
#   'these',
#   'pieces',
#   'of',
#   'rubber',
#   'metal',
#   'or',
#   'other',
#   'plates',
#   'which',
#   'will',
#   'prevent',
#   'the',
#   'rubber',
#   'from',
#   'adhering',
#   'together',
#   'when',
#   'pressure',
#   'is',
#   'applied',
#   'and',
#   'thus',
#   'or',
#   'more',
#   'pockets',
#   'will',
#   'be',
#   'formed',
#   'in',
#   'which',
#   'to',
#   'place',
#   'cigarette',
#   'paper',
#   'books',
#   'or',
#   'matches',
#   'on',
#   'either',
#   'side',
#   'of',
#   'this',
#   'foundation',
#   'piece',
#   'a',
#   'similarly',
#   'shaped',
#   'piece',
#   'of',
#   'plastic',
#   'rubber',
#   'compound',
#   'is',
#   'attached',
#   'by',
#   'its',
#   'edges',
#   'and',
#   'into',
#   'the',
#   'spaces',
#   'between',
#   'the',
#   'external',
#   'pieces',
#   'and',
#   'the',
#   'foundation',
#   'plate',
#   'a',
#   'suitable',
#   'quantity',
#   'of',
#   'water',
#   'or',
#   'other',
#   'liquid',
#   'is',
#   'injected',
#   'the',
#   'opening',
#   'left',
#   'for',
#   'this',
#   'purpose',
#   'being',
#   'immediately',
#   'closed',
#   'up',
#   'a',
#   'cap',
#   'piece',
#   'of',
#   'sheet',
#   'rubber',
#   'of',
#   'suitable',
#   'form',
#   'is',
#   'next',
#   'applied',
#   'to',
#   'the',
#   'pouch',
#   'and',
#   'is',
#   'secured',
#   'to',
#   'the',
#   'straight',
#   'edge',
#   'thereof',
#   'by',
#   'solution',
#   'which',
#   'when',
#   'pressure',
#   'is',
#   'applied',
#   'causes',
#   'the',
#   'cap',
#   'piece',
#   'to',
#   'adhere',
#   'to',
#   'the',
#   'body',
#   'of',
#   'the',
#   'pouch',
#   'some',
#   'powdered',
#   'talc',
#   'or',
#   'other',
#   'suitable',
#   'material',
#   'is',
#   'inserted',
#   'under',
#   'the',
#   'cap',
#   'piece',
#   'to',
#   'prevent',
#   'it',
#   'adhering',
#   'to',
#   'the',
#   'body',
#   'of',
#   'the',
#   'pouch',
#   'except',
#   'at',
#   'those',
#   'parts',
#   'which',
#   'have',
#   'received',
#   'the',
#   'solution',
#   'the',
#   'formed',
#   'article',
#   'is',
#   'now',
#   'placed',
#   'in',
#   'the',
#   'mould',
#   'to',
#   'be',
#   'vulcanized',
#   'in',
#   'the',
#   'usual',
#   'manner',
#   'after',
#   'vulcanization',
#   'all',
#   'the',
#   'joins',
#   'will',
#   'be',
#   'found',
#   'firmly',
#   'united',
#   'together',
#   'and',
#   'the',
#   'pouch',
#   'will',
#   'be',
#   'set',
#   'according',
#   'to',
#   'the',
#   'form',
#   'of',
#   'the',
#   'mould',
#   'to',
#   'open',
#   'the',
#   'pouch',
#   'and',
#   'let',
#   'out',
#   'the',
#   'water',
#   'it',
#   'will',
#   'be',
#   'necessary',
#   'to',
#   'turn',
#   'back',
#   'the',
#   'cap',
#   'piece',
#   'and',
#   'open',
#   'the',
#   'pockets',
#   'in',
#   'which',
#   'the',
#   'water',
#   'is',
#   'enclosed',
#   'by',
#   'running',
#   'a',
#   'sharp',
#   'knife',
#   'along',
#   'the',
#   'joint',
#   'at',
#   'the',
#   'straight',
#   'end',
#   'of',
#   'the',
#   'pouch',
#   'after',
#   'which',
#   'the',
#   'metal',
#   'or',
#   'other',
#   'plates',
#   'are',
#   'drawn',
#   'out',
#   'of',
#   'their',
#   'pockets',
#   'in',
#   'the',
#   'foundation',
#   'piece',
#   'and',
#   'the',
#   'moulded',
#   'india',
#   'rubber',
#   'tobacco',
#   'pouch',
#   'containing',
#   'pockets',
#   'for',
#   'tobacco',
#   'and',
#   'various',
#   'smaller',
#   'pockets',
#   'is',
#   'completed',
#   'specification',
#   'in',
#   'pursuance',
#   'of',
#   'the',
#   'conditions',
#   'of',
#   'the',
#   'letters',
#   'patent',
#   'filed',
#   'by',
#   'the',
#   'said',
#   'james',
#   'burbridge',
#   'in',
#   'the',
#   'great',
#   'seal',
#   'patent',
#   'office',
#   'on',
#   'the',
#   'august',
#   'james',
#   'burbridge',
#   'manager',
#   'at',
#   'messrs.',
#   'warne',
#   'co.',
#   "'s",
#   'india',
#   'rubber',
#   'works',
#   'tottenham',
#   'middlesex',
#   'improvements',
#   'in',
#   'tobacco',
#   'pouches',
#   'this',
#   'invention',
#   'relates',
#   'to',
#   'a',
#   'novel',
#   'construction',
#   'of',
#   'pouch',
#   'to',
#   'be',
#   'used',
#   'for',
#   'the',
#   'reception',
#   'of',
#   'tobacco',
#   'fusees',
#   'and',
#   'other',
#   'materials',
#   'used',
#   'by',
#   'smokers',
#   'the',
#   'object',
#   'being',
#   'to',
#   'obtain',
#   'a',
#   'compact',
#   'and',
#   'secure',
#   'receptacle',
#   'for',
#   'such',
#   'articles',
#   'in',
#   'the',
#   'accompanying',
#   'drawing',
#   'i',
#   'have',
#   'shewn',
#   'my',
#   'improved',
#   'pouch',
#   'in',
#   'front',
#   'view',
#   'at',
#   'fig',
#   'and',
#   'in',
#   'cross',
#   'section',
#   'at',
#   'fig',
#   'in',
#   'manufacturing',
#   'this',
#   'improved',
#   'pouch',
#   'i',
#   'cut',
#   'from',
#   'a',
#   'sheet',
#   'of',
#   'plastic',
#   'rubber',
#   'compound',
#   'pieces',
#   'of',
#   'semi',
#   'elliptical',
#   'form',
#   'and',
#   'corresponding',
#   'size',
#   'such',
#   'as',
#   'that',
#   'shewn',
#   'in',
#   'fig',
#   '1a',
#   'and',
#   'place',
#   'them',
#   'back',
#   'to',
#   'back',
#   'so',
#   'as',
#   'to',
#   'form',
#   'a',
#   'foundation',
#   'or',
#   'stiffening',
#   'piece',
#   'for',
#   'the',
#   'pouch',
#   'between',
#   'these',
#   'pieces',
#   'of',
#   'rubber',
#   'shewn',
#   'in',
#   'cross',
#   'section',
#   'at',
#   'a',
#   'a',
#   'fig',
#   'i',
#   'insert',
#   'or',
#   'more',
#   'metal',
#   'or',
#   'other',
#   'plates',
#   'to',
#   'prevent',
#   'the',
#   'rubber',
#   'pieces',
#   'a',
#   'a',
#   'from',
#   'adhering',
#   'together',
#   'when',
#   'pressure',
#   'is',
#   'applied',
#   'and',
#   'thus',
#   'or',
#   'more',
#   'pockets',
#   'will',
#   'be',
#   'formed',
#   'in',
#   'the',
#   'foundation',
#   'or',
#   'stiffening',
#   'piece',
#   'suitable',
#   'for',
#   'receiving',
#   'cigarette',
#   'paper',
#   'books',
#   'as',
#   'shewn',
#   'at',
#   'fig',
#   'or',
#   'matches',
#   'and',
#   'other',
#   'materials',
#   'used',
#   'by',
#   'smokers',
#   'on',
#   'either',
#   'side',
#   'of',
#   'this',
#   'foundation',
#   'piece',
#   'i',
#   'attach',
#   'similarly',
#   'shaped',
#   'pieces',
#   'b',
#   'b',
#   'of',
#   'plastic',
#   'rubber',
#   'compound',
#   'and',
#   'into',
#   'the',
#   'spaces',
#   'between',
#   'these',
#   'external',
#   'pieces',
#   'and',
#   'the',
#   'foundation',
#   'plate',
#   'i',
#   'inject',
#   'water',
#   'or',
#   'other',
#   'suitable',
#   'liquid',
#   'the',
#   'opening',
#   'left',
#   'for',
#   'this',
#   'purpose',
#   'being',
#   'immediately',
#   'afterwards',
#   'closed',
#   'up',
#   'i',
#   'next',
#   'apply',
#   'to',
#   'the',
#   'pouch',
#   'a',
#   'cap',
#   'piece',
#   'c',
#   'of',
#   'sheet',
#   'rubber',
#   'and',
#   'i',
#   'secure',
#   'it',
#   'to',
#   'the',
#   'straight',
#   'edge',
#   'and',
#   'ends',
#   'thereof',
#   'by',
#   'a',
#   'solution',
#   'of',
#   'india',
#   'rubber',
#   'which',
#   'when',
#   'pressure',
#   'is',
#   'applied',
#   'causes',
#   'the',
#   'cap',
#   'piece',
#   'to',
#   'adhere',
#   'to',
#   'the',
#   'body',
#   'of',
#   'the',
#   'pouch',
#   'in',
#   'order',
#   'to',
#   'prevent',
#   'the',
#   'cap',
#   'piece',
#   'c',
#   'adhering',
#   'to',
#   'the',
#   'body',
#   'of',
#   'the',
#   'pouch',
#   'except',
#   'at',
#   'those',
#   'parts',
#   'which',
#   'have',
#   'received',
#   'the',
#   'solution',
#   'i',
#   'insert',
#   'some',
#   'powdered',
#   'tale',
#   'or',
#   'other',
#   'suitable',
#   'material',
#   'under',
#   'the',
#   'cap',
#   'piece',
#   'before',
#   'the',
#   'pouch',
#   'is',
#   'vulcanized',
#   'the',
#   'article',
#   'thus',
#   'far',
#   'manufactured',
#   'i',
#   'place',
#   'in',
#   'a',
#   'mould',
#   'suitably',
#   'formed',
#   'and',
#   'proportioned',
#   'to',
#   'impart',
#   'to',
#   'the',
#   'pouch',
#   'the',
#   'required',
#   'form',
#   'during',
#   'the',
#   'process',
#   'of',
#   'vulcanization',
#   'during',
#   'the',
#   'vulcanizing',
#   'operation',
#   'the',
#   'water',
#   'or',
#   'other',
#   'liquid',
#   'confined',
#   'in',
#   'the',
#   'pouch',
#   'will',
#   'be',
#   'converted',
#   'into',
#   'steam',
#   'which',
#   'will',
#   'expand',
#   'and',
#   'distend',
#   'the',
#   'rubber',
#   'causing',
#   'it',
#   'to',
#   'completely',
#   'fill',
#   'the',
#   'mould',
#   'and',
#   'at',
#   'the',
#   'same',
#   'time',
#   'firmly',
#   'unite',
#   'the',
#   'joinings',
#   'and',
#   'give',
#   'to',
#   'the',
#   'pouch',
#   'a',
#   'permanent',
#   'set',
#   'corresponding',
#   'to',
#   'the',
#   'internal',
#   'form',
#   'of',
#   'the',
#   'mould',
#   'when',
#   'the',
#   'vulcanizing',
#   'process',
#   'is',
#   'completed',
#   'i',
#   'turn',
#   'back',
#   'the',
#   'cap',
#   'piece',
#   'and',
#   'open',
#   'the',
#   'pockets',
#   'in',
#   'which',
#   'the',
#   'water',
#   'is',
#   'enclosed',
#   'by',
#   'running',
#   'a',
#   'sharp',
#   'knife',
#   'along',
#   'the',
#   'joining',
#   'at',
#   'the',
#   'straight',
#   'end',
#   'of',
#   'the',
#   'pouch',
#   'and',
#   'let',
#   'out',
#   'the',
#   'water',
#   'i',
#   'then',
#   'run',
#   'the',
#   'knife',
#   'along',
#   'the',
#   'joinings',
#   'at',
#   'the',
#   'part',
#   'or',
#   'parts',
#   'where',
#   'the',
#   'pockets',
#   'in',
#   'the',
#   'stiffening',
#   'pieces',
#   'are',
#   'formed',
#   'and',
#   'remove',
#   'the',
#   'enclosed',
#   'metal',
#   'or',
#   'other',
#   'plates',
#   'the',
#   'moulded',
#   'india',
#   'rubber',
#   'tobacco',
#   'pouch',
#   'containing',
#   'side',
#   'pockets',
#   'for',
#   'tobacco',
#   'and',
#   'a',
#   'central',
#   'pocket',
#   'or',
#   'pockets',
#   'for',
#   'the',
#   'reception',
#   'of',
#   'cigarette',
#   'paper',
#   'books',
#   'matches',
#   'and',
#   'other',
#   'paraphernalia',
#   'of',
#   'the',
#   'smoker',
#   'is',
#   'now',
#   'complete',
#   'at',
#   'figures',
#   'and',
#   'i',
#   'have',
#   'shewn',
#   'a',
#   'modified',
#   'form',
#   'of',
#   'cover',
#   'for',
#   'closing',
#   'side',
#   'of',
#   'my',
#   'improved',
#   'pouch',
#   'fig',
#   'is',
#   'a',
#   'front',
#   'view',
#   'and',
#   'fig',
#   ...],
#  'predicted_BPO_classes': ['Tobacco']}

# %%
# here we visualize a dictionary of entities
dataset_all_entities['train'][123456]
# Out:
# {'patent_id': 'GB186100760A',
#  'year': 1861,
#  'front_page_entities': [{'class': 'DATE',
#    'entity_text': '26th March 1861.',
#    'start': 119,
#    'end': 135,
#    'person_id': None,
#    'inventor_id': None,
#    'latitude': None,
#    'longitude': None},
#   {'class': 'PER',
#    'entity_text': 'Hannah Emes',
#    'start': 34,
#    'end': 45,
#    'person_id': [1],
#    'inventor_id': 82258,
#    'latitude': None,
#    'longitude': None},
#   {'class': 'ADD',
#    'entity_text': "St. John's Villas, Adelaide Road, Hampstead, in the County of Middlesex",
#    'start': 155,
#    'end': 226,
#    'person_id': [1],
#    'inventor_id': None,
#    'latitude': 51.5545,
#    'longitude': -0.174}]}

# %% [markdown]
# #### HF datasets --> pandas dataframes

# %%
# convert each HF dataset to pandas
df_years = dataset_all_years["train"].to_pandas()
df_entities = dataset_all_entities["train"].to_pandas()

# %%
# merge on patent_id
df_merged = pd.merge(df_years, df_entities, on="patent_id", how="inner")

# %% [markdown]
# #### Build a csv of unique patent-inventors

# %%
# get entities dataframe
def process_huggingface_dataset(hf_dataset):

    all_records = []

    for row in hf_dataset["train"]:

        patent_id = row["patent_id"]

        year = row["year"]

        person_data = {}

        # process and store 'PER' entity information
        for entity in row["front_page_entities"]:

            if entity["class"] == "PER":

                for pid in entity["person_id"]:

                    if pid not in person_data:

                        # initialize columns
                        person_data[pid] = {
                            "patent_id": patent_id,
                            "inventor_id": entity.get("inventor_id"),
                            "year": year,
                            "name": entity["entity_text"],
                            "occupation": None,
                            "address": None,
                            "firm": None,
                        }

        # map 'OCC', 'ADD', 'FIRM' to 'PER' using 'person_id'
        for entity in row["front_page_entities"]:

            if entity["class"] in ["OCC", "ADD", "FIRM"]:

                for pid in entity["person_id"]:

                    if pid in person_data:

                        if entity["class"] == "OCC" and person_data[pid]["occupation"] is None:
                            person_data[pid]["occupation"] = entity["entity_text"]

                        elif entity["class"] == "ADD" and person_data[pid]["address"] is None:
                            person_data[pid]["address"] = entity["entity_text"]

                        elif entity["class"] == "FIRM" and person_data[pid]["firm"] is None:
                            person_data[pid]["firm"] = entity["entity_text"]

        all_records.extend(list(person_data.values()))

    return pd.DataFrame(all_records)


entities_df = process_huggingface_dataset(dataset_all_entities)
entities_df
# Out:
#            patent_id  inventor_id  year                     name  \
# 0       GB167800201A        24518  1678           CHARLES HOWARD
# 1       GB167800203A       106090  1678             JOHN ROBERTS
# 2       GB167800206A        59762  1678                   GEORGE
# 3       GB167800206A       136363  1678  Lord Viscount GRANDISON
# 4       GB167800205A       153725  1678        ROBERT LEDGINGHAM
# ...              ...          ...   ...                      ...
# 395936  GB179702163A       100315  1797      JOHN FALCONER ATLEE
# 395937  GB179702176A       110304  1797            JOSEPH BARTON
# 395938  GB179702205A        94617  1797             JAMES WELDON
# 395939  GB179702188A        84166  1797            Henry Johnson
# 395940  GB179702181A       151586  1797           RICHARD VARLEY
#
#                               occupation  \
# 0                                Esquire
# 1                                Esquire
# 2                                   None
# 3                                   None
# 4                               Merchant
# ...                                  ...
# 395936                         Distiller
# 395937                           Chymist
# 395938                          Engineer
# 395939                         Gentleman
# 395940  Merchant and Cotton Manufacturer
#
#                                                   address  firm
# 0                                                    None  None
# 1                                                    None  None
# 2                                                    None  None
# 3                                                    None  None
# 4                                         Citty of London  None
# ...                                                   ...   ...
# 395936                Wandsworth, in the County of Surrey  None
# 395937  Parish of Saint Botolpli, Bishopsgate, in tlie...  None
# 395938              Litchfield, in the County of Stafford  None
# 395939                                             London  None
# 395940  Damside, near Bolton-le-Moors, in the County P...  None
#
# [395941 rows x 7 columns]

# %%
# save as csv
entities_df.to_csv("patent_inventors.csv")

# %%
unique_inventors_count = entities_df["inventor_id"].nunique()
print(f"Number of unique inventors: {unique_inventors_count}")
# Out:
# Number of unique inventors: 205082

# %% [markdown]
# ## Try our named entity recognition models

# %% [markdown]
# Our NER models are available here:
# - For entities: https://huggingface.co/matthewleechen/patent_entities_ner.
# - For titles: https://huggingface.co/matthewleechen/patent_titles_ner.

# %%
ent_model_repo = "matthewleechen/patent_entities_ner" # for extracting named entities from the front page
title_model_repo = "matthewleechen/patent_titles_ner" # for extracting titles from the front page

# set entity tokenizer + model
ent_tokenizer = AutoTokenizer.from_pretrained(ent_model_repo)
ent_model = AutoModelForTokenClassification.from_pretrained(ent_model_repo)

# set title tokenizer + model
title_tokenizer = AutoTokenizer.from_pretrained(title_model_repo)
title_model = AutoModelForTokenClassification.from_pretrained(title_model_repo)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
# a custom recognizer that reconstructs HF pipelines entities

def recognizer(text, model, tokenizer):

    # HF ner pipeline
    token_level_results = pipeline("ner", model=model, tokenizer=tokenizer)(text)

    # keep entities tracked
    entities = []
    current_entity = None

    for item in token_level_results:

        tag = item['entity']

        # replace '▁' with space for easier reading (_ is created by the XLM-RoBERTa tokenizer)
        word = item['word'].replace('▁', ' ')

        # aggregate I-O-B tagged entities
        if tag.startswith('B-'):

            if current_entity:
                entities.append(current_entity)

            current_entity = {'type': tag[2:], 'text': word.strip(), 'start': item['start'], 'end': item['end']}

        elif tag.startswith('I-'):

            if current_entity and tag[2:] == current_entity['type']:
                current_entity['text'] += word
                current_entity['end'] = item['end']

            else:

                if current_entity:
                    entities.append(current_entity)

                current_entity = {'type': tag[2:], 'text': word.strip(), 'start': item['start'], 'end': item['end']}

        else:
            # deal with O tag
            if current_entity:
                entities.append(current_entity)
            current_entity = None


    if current_entity:

        # add to entities
        entities.append(current_entity)


    # track entity merges
    merged_entities = []

    # merge entities of the same type
    for entity in entities:

        if merged_entities and merged_entities[-1]['type'] == entity['type'] and merged_entities[-1]['end'] == entity['start']:
            merged_entities[-1]['text'] += entity['text']
            merged_entities[-1]['end'] = entity['end']

        else:
            merged_entities.append(entity)

    # clean up extra spaces
    for entity in merged_entities:
        entity['text'] = ' '.join(entity['text'].split())

    # convert to list of dicts
    return [{'class': entity['type'],
             'entity_text': entity['text'],
             'start': entity['start'],
             'end': entity['end']} for entity in merged_entities]

# %%
# let's try out an example
example = """
LETTERS PATENT to James Burbridge, Manager at Messrs. W. Warne and Co.\'s\nIndia Rubber Works, Tottenham, Middlesex, for an Invention of "IMPROVE-\nMENTS IN TOBACCO-POUCHES."\nPROVISIONAL SPECIFICATION left by the said James Burbridge at the\nOffice of the Commissioners of Patents on the 26th February 1881.\nJAMES BURBRIDGE, Manager at Messrs. W. Warne & Co.\'s India Rubber Works,\nTottenham, Middlesex. "IMPROVEMENTS IN TOBACCO POUCHES."\nThis Invention relates to a novel construction of pouch to be used for the\nreception of tobacco, fusees, and other materials used by smokers, the object being\nto obtain a compact and secure receptacle for such articles.\nTo this end we cut from a sheet of plastic rubber compound 2 pieces of any\ndesired form, say semi elliptical, and of corresponding size, and place them together\nback to back so as to form a foundation or stiffening piece for the pouch. If\ndesired, we may insert at different places between these two pieces of rubber metal\nor other plates which will prevent the rubber from adhering together when pressure\nis applied, and thus one, two, or more pockets will be formed in which to place\ncigarette paper books or matches. On either side of this foundation piece a\nsimilarly shaped piece of plastic rubber compound is attached by its edges, and\ninto the spaces between the external pieces and the foundation plate a suitable\nquantity of water or other liquid is injected, the opening left for this purpose being\nimmediately closed up.\nA cap piece of sheet rubber of suitable form is next applied to the pouch, and is\nsecured to the straight edge thereof by solution, which, when pressure is applied,\ncauses the cap piece to adhere to the body of the pouch.\nSome powdered talc or other suitable material is inserted under the cap piece\nto prevent it adhering to the body of the pouch, except at those parts which have\nreceived the solution.
"""

# %%
# return the extracted entities
recognizer(example, ent_model, ent_tokenizer)
# Out:
# Device set to use cpu
# [{'class': 'PER', 'entity_text': 'James Burbridge', 'start': 19, 'end': 34},
#  {'class': 'OCC', 'entity_text': 'Manager', 'start': 36, 'end': 43},
#  {'class': 'FIRM',
#   'entity_text': "Messrs. W. Warne and Co.'s",
#   'start': 47,
#   'end': 73},
#  {'class': 'FIRM',
#   'entity_text': 'India Rubber Works',
#   'start': 74,
#   'end': 92},
#  {'class': 'ADD',
#   'entity_text': 'Tottenham, Middlesex',
#   'start': 94,
#   'end': 114},
#  {'class': 'PER', 'entity_text': 'James Burbridge', 'start': 216, 'end': 231},
#  {'class': 'DATE',
#   'entity_text': '26th February 1881.',
#   'start': 285,
#   'end': 304},
#  {'class': 'PER', 'entity_text': 'JAMES BURBRIDGE', 'start': 305, 'end': 320},
#  {'class': 'OCC', 'entity_text': 'Manager', 'start': 322, 'end': 329},
#  {'class': 'FIRM',
#   'entity_text': "Messrs. W. Warne & Co.'s",
#   'start': 333,
#   'end': 357},
#  {'class': 'ADD',
#   'entity_text': 'Tottenham, Middlesex.',
#   'start': 378,
#   'end': 399}]

# %%
# return the extracted title
recognizer(example, title_model, title_tokenizer)
# Out:
# Device set to use cpu
# [{'class': 'TITLE',
#   'entity_text': 'IMPROVE- MENTS IN TOBACCO-POUCHES',
#   'start': 137,
#   'end': 170}]

# %% [markdown]
# ## Try our patent classification model

# %% [markdown]
# Our patent classification model is available at: https://huggingface.co/matthewleechen/multilabel_patent_classifier.

# %%
class_model_repo = "matthewleechen/multilabel_patent_classifier" # for extracting named entities from the front page

# set classifier tokenizer + model
class_tokenizer = AutoTokenizer.from_pretrained(class_model_repo)
class_model = AutoModelForSequenceClassification.from_pretrained(class_model_repo)

# %%
# return labels function
def get_class_labels(text, threshold=0.5):

    # pipeline returns a list of lists e.g. [[{'label':'LABEL1', 'score':0.8}, {'label':'LABEL2', 'score':0.2}, ...]]
    # grab the first (and only) item: a list of dicts for this text
    output = pipeline(task="text-classification", model=class_model, tokenizer=class_tokenizer, top_k=None)(text)[0]

    # convert to dict {label -> score}
    label_scores = {item['label']: item['score'] for item in output}

    # filter for sigmoid threshold
    return [label for label, score in label_scores.items() if score >= threshold]

# %%
# feed a title as an example
example_title = "IMPROVE- MENTS IN TOBACCO-POUCHES"
labels = get_class_labels(example_title)
print(labels)
# Out:
# ['Tobacco']
